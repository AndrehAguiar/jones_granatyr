# %% [markdown]
# # Tarefa: Série temporal da poluição na China
#
# No exemplo sobre a previsão dos valores das ações, nós trabalhamos com uma série temporal que apresenta os valores dia a dia. Porém, também podemos utilizar outros formatos de data, como por exemplo: horas, minutos ou segundos (dependendo do contexto). A base de dados desta tarefa possui essas características, na qual temos em cada registro o <b>ano, o mês, o dia e a hora</b> juntamente com o valor de poluição naquele momento e algumas características climáticas. Na imagem abaixo você pode visualizar alguns registros

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# O atributo `No` é somente a contagem de registros (como uma chave primária), o `year`, `month`, `day` e `hour` indicam a dimensão temporal (de hora em hora); o atributo `pm2.5` diz respeito ao nível de poluição (que faremos a previsão) e por fim, todos os outros atributos serão os previsores. Baseado nos atributos previsores, a ideia é indicar o nível de poluição em uma determinada hora.
#
# Siga as seguintes dicas para essa atividade:
#
# - Use a função `dropna()` para excluir valores faltantes
#
# - Os atributos `No`, `year`, `month`, `day`, `hour` e `cbwd` devem ser excluídos, pois em uma série temporal essas informações não são importantes (o `cbwd` é somente um campo string)
#
# - Este é um problema com uma única saída (`pm2.5`) e múltiplos previsores
#
# - Você pode testar com vários valores de intervalos de tempo (começando com 10, por exemplo)
#
# - Você pode optar por dividir a base de dados entre treinamento e teste ou usar a própria base de dados de treinamento (em nossa implementação usamos a própria base de treinamento)
#
# Depois de treinar a rede neural, gere o gráfico para visualizar os resultados das previsões. Abaixo você pode visualizar o gráfico com os nossos resultados

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# !pip install torch==1.4.0
# Out:
# Collecting torch==1.4.0
#   Downloading https://files.pythonhosted.org/packages/1a/3b/fa92ece1e58a6a48ec598bab327f39d69808133e5b2fb33002ca754e381e/torch-1.4.0-cp37-cp37m-manylinux1_x86_64.whl (753.4MB)
#      |████████████████████████████████| 753.4MB 18kB/s
# ERROR: torchvision 0.8.2+cu101 has requirement torch==1.7.1, but you'll have torch 1.4.0 which is incompatible.
# Installing collected packages: torch
#   Found existing installation: torch 1.7.1+cu101
#     Uninstalling torch-1.7.1+cu101:
#       Successfully uninstalled torch-1.7.1+cu101
# Successfully installed torch-1.4.0

# %% [markdown]
# ## Etapa 1: Importação das bibliotecas

# %%
import torch
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from torch import nn, optim
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import train_test_split

# %%
torch.manual_seed(123)

# %% [markdown]
# ## Etapa 2: Base de dados

# %%
df = pd.read_csv('/content/poluicao.csv')
df.head()
# Out:
#    No  year  month  day  hour  pm2.5  DEWP  TEMP    PRES cbwd    Iws  Is  Ir
# 0   1  2010      1    1     0    NaN   -21 -11.0  1021.0   NW   1.79   0   0
# 1   2  2010      1    1     1    NaN   -21 -12.0  1020.0   NW   4.92   0   0
# 2   3  2010      1    1     2    NaN   -21 -11.0  1019.0   NW   6.71   0   0
# 3   4  2010      1    1     3    NaN   -21 -14.0  1019.0   NW   9.84   0   0
# 4   5  2010      1    1     4    NaN   -20 -12.0  1018.0   NW  12.97   0   0

# %%
df.tail()
# Out:
#           No  year  month  day  hour  pm2.5  ...  TEMP    PRES  cbwd     Iws  Is  Ir
# 43819  43820  2014     12   31    19    8.0  ...  -2.0  1034.0    NW  231.97   0   0
# 43820  43821  2014     12   31    20   10.0  ...  -3.0  1034.0    NW  237.78   0   0
# 43821  43822  2014     12   31    21   10.0  ...  -3.0  1034.0    NW  242.70   0   0
# 43822  43823  2014     12   31    22    8.0  ...  -4.0  1034.0    NW  246.72   0   0
# 43823  43824  2014     12   31    23   12.0  ...  -3.0  1034.0    NW  249.85   0   0
#
# [5 rows x 13 columns]

# %%
df.isnull().sum()
# Out:
# No          0
# year        0
# month       0
# day         0
# hour        0
# pm2.5    2067
# DEWP        0
# TEMP        0
# PRES        0
# cbwd        0
# Iws         0
# Is          0
# Ir          0
# dtype: int64

# %%
df.dropna(inplace=True)
df.isnull().sum()
# Out:
# No       0
# year     0
# month    0
# day      0
# hour     0
# pm2.5    0
# DEWP     0
# TEMP     0
# PRES     0
# cbwd     0
# Iws      0
# Is       0
# Ir       0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 41757 entries, 24 to 43823
# Data columns (total 13 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   No      41757 non-null  int64
#  1   year    41757 non-null  int64
#  2   month   41757 non-null  int64
#  3   day     41757 non-null  int64
#  4   hour    41757 non-null  int64
#  5   pm2.5   41757 non-null  float64
#  6   DEWP    41757 non-null  int64
#  7   TEMP    41757 non-null  float64
#  8   PRES    41757 non-null  float64
#  9   cbwd    41757 non-null  object
#  10  Iws     41757 non-null  float64
#  11  Is      41757 non-null  int64
#  12  Ir      41757 non-null  int64
# dtypes: float64(4), int64(8), object(1)
# memory usage: 4.5+ MB

# %%
df.drop(['No', 'year','month','day','hour','cbwd'], axis=1, inplace=True)
df.head()
# Out:
#     pm2.5  DEWP  TEMP    PRES   Iws  Is  Ir
# 24  129.0   -16  -4.0  1020.0  1.79   0   0
# 25  148.0   -15  -4.0  1020.0  2.68   0   0
# 26  159.0   -11  -5.0  1021.0  3.57   0   0
# 27  181.0    -7  -5.0  1022.0  5.36   1   0
# 28  138.0    -7  -5.0  1022.0  6.25   2   0

# %%
data_raw = df.values

# %%
scaler = MinMaxScaler(feature_range=(0,1))
data_scaled = scaler.fit_transform(data_raw)

# %%
X, y = [], []

for i in range(10, data_scaled.shape[0]):
  X.append(data_scaled[i-10:i, 1:])
  y.append(data_scaled[i, 0])

X, y = np.array(X), np.array(y)

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, random_state=123, test_size=0.15, shuffle=True)

X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((35484, 10, 6), (6263, 10, 6), (35484,), (6263,))

# %%
X_train = torch.tensor(X_train, dtype=torch.float32)
y_train = torch.tensor(y_train, dtype=torch.float32)
type(X_train), type(y_train)
# Out:
# (torch.Tensor, torch.Tensor)

# %%
dataset = torch.utils.data.TensorDataset(X_train, y_train)
loader = torch.utils.data.DataLoader(dataset, batch_size=64, shuffle=True)

# %% [markdown]
# ## Etapa 3: Construção da rede neural recorrente

# %%
class Reg_LSTM(nn.Module):
  def __init__(self):
    super(Reg_LSTM, self).__init__()

    self.lstm0 = nn.LSTM(input_size=6, hidden_size=100)
    self.lstm1 = nn.LSTM(100, 50)
    self.lstm2 = nn.LSTM(50,50, dropout=0.3, num_layers=2)
    self.dropout = nn.Dropout(p=0.3)
    self.linear = nn.Linear(in_features=50, out_features=1)

  def forward(self, X):
    X = X.permute(1,0,2)
    X, _ = self.lstm0(X)
    X = self.dropout(X)
    X, _ = self.lstm1(X)
    X = self.dropout(X)
    X, _ = self.lstm2(X)    
    X = self.dropout(X)
    X = self.linear(X)

    return X

# %%
device = torch.device('cuda') if torch.cuda.is_available else torch.device('cpu')
device
# Out:
# device(type='cuda')

# %%
reg = Reg_LSTM()
criterion = nn.MSELoss()
optimizer = optim.Adam(reg.parameters())
reg.to(device)
# Out:
# Reg_LSTM(
#   (lstm0): LSTM(6, 100)
#   (lstm1): LSTM(100, 50)
#   (lstm2): LSTM(50, 50, num_layers=2, dropout=0.3)
#   (dropout): Dropout(p=0.3, inplace=False)
#   (linear): Linear(in_features=50, out_features=1, bias=True)
# )

# %% [markdown]
# ## Etapa 4: Treinamento do modelo

# %%
# Variáveis para o callback
ES_MIN_DELTA = 1e-10
ES_PATIENCE = 10
RLR_FACTOR = 0.2
RLR_PATIENCE = 5

# Inicializando o custo inicial para usar o callback
min_loss = np.inf

# %%
arr_loss, arr_mae = [], []
for epoch in range(200):

  run_loss = 0.
  run_mae = 0.

  for i, data in enumerate(loader):
    
    inputs, labels = data
    inputs, labels = inputs.to(device), labels.to(device)

    optimizer.zero_grad()

    outputs = reg(inputs)
    outputs = outputs[-1]
    outputs = outputs.view(*labels.shape)

    loss = criterion(outputs, labels)
    loss.backward()

    optimizer.step()

    run_loss += loss.item()
    mae = mean_absolute_error(labels.detach().cpu().numpy().flatten(),
                              outputs.detach().cpu().numpy().flatten())
    
    run_mae += mae

    print('\rÉpoca {:3d} - Loop {:3d} de {:3d}: custo {:03.5f} | MAE {:03.5f}' \
          .format(epoch+1, i+1, len(loader), loss, mae), end='\r')
    
  run_loss /= len(loader)
  run_mae /= len(loader)
  arr_loss.append(run_loss)
  arr_mae.append(run_mae)
  print('ÉPOCA {:3d} FINALIZADA: custo {:03.6f} | MAE {:03.6f}      ' \
        .format(epoch+1, run_loss, run_mae))


  # SALVAR O MODELO
  if run_loss < min_loss:
    print('** Custo reduzido de {:03.6f} >>> {:03.6f} ... SALVANDO CHECKPOINT\n' \
          .format(min_loss, run_loss))
    torch.save(reg.state_dict(), 'checkpoint.pth')
    min_loss = run_loss
    es_patience = 0
    rlr_patience = 0

  else:
    print('**Custo não reduziu, não salva checkpoint\n')
    # OS DEMAIS PARÂMETROS SÓ SERÃO CONSIDERADOS SE O CUSTO NÃO TIVER
    # PARADA ANTECIPADA
    if run_loss - min_loss >= ES_MIN_DELTA:
      es_patience += 1

      if es_patience == ES_PATIENCE:
        print('--Critério de parada antecipada alcaçado, parando o treinamento.')
        break

    # REDUZIR A TAXA DE APRENDIZAGEM
    rlr_patience += 1
    if rlr_patience == RLR_PATIENCE:
      print('--Critério de redução de taxa de aprendizagem alcançado, reduzindo LR.')
      for param_group in optimizer.param_groups:
        param_group['lr'] *= RLR_FACTOR
      
      rlr_patience = 0
# Out:
# ÉPOCA   1 FINALIZADA: custo 0.007958 | MAE 0.064816
# ** Custo reduzido de inf >>> 0.007958 ... SALVANDO CHECKPOINT
#
# ÉPOCA   2 FINALIZADA: custo 0.006265 | MAE 0.056313
# ** Custo reduzido de 0.007958 >>> 0.006265 ... SALVANDO CHECKPOINT
#
# ÉPOCA   3 FINALIZADA: custo 0.005673 | MAE 0.053048
# ** Custo reduzido de 0.006265 >>> 0.005673 ... SALVANDO CHECKPOINT
#
# ÉPOCA   4 FINALIZADA: custo 0.005445 | MAE 0.051751
# ** Custo reduzido de 0.005673 >>> 0.005445 ... SALVANDO CHECKPOINT
#
# ÉPOCA   5 FINALIZADA: custo 0.005360 | MAE 0.051205
# ** Custo reduzido de 0.005445 >>> 0.005360 ... SALVANDO CHECKPOINT
#
# ÉPOCA   6 FINALIZADA: custo 0.005202 | MAE 0.050588
# ** Custo reduzido de 0.005360 >>> 0.005202 ... SALVANDO CHECKPOINT
#
# ÉPOCA   7 FINALIZADA: custo 0.005156 | MAE 0.050070
# ** Custo reduzido de 0.005202 >>> 0.005156 ... SALVANDO CHECKPOINT
#
# ÉPOCA   8 FINALIZADA: custo 0.005072 | MAE 0.049677
# ** Custo reduzido de 0.005156 >>> 0.005072 ... SALVANDO CHECKPOINT
#
# ÉPOCA   9 FINALIZADA: custo 0.005032 | MAE 0.049531
# ** Custo reduzido de 0.005072 >>> 0.005032 ... SALVANDO CHECKPOINT
#
# ÉPOCA  10 FINALIZADA: custo 0.005036 | MAE 0.049521
# **Custo não reduziu, não salva checkpoint
#
# ÉPOCA  11 FINALIZADA: custo 0.004975 | MAE 0.049178
# ** Custo reduzido de 0.005032 >>> 0.004975 ... SALVANDO CHECKPOINT
#
# ÉPOCA  12 FINALIZADA: custo 0.004914 | MAE 0.048842
# ** Custo reduzido de 0.004975 >>> 0.004914 ... SALVANDO CHECKPOINT
#
# ÉPOCA  13 FINALIZADA: custo 0.004911 | MAE 0.048805
# ** Custo reduzido de 0.004914 >>> 0.004911 ... SALVANDO CHECKPOINT
#
# ÉPOCA  14 FINALIZADA: custo 0.004880 | MAE 0.048682
# ** Custo reduzido de 0.004911 >>> 0.004880 ... SALVANDO CHECKPOINT
#
# ÉPOCA  15 FINALIZADA: custo 0.004841 | MAE 0.048430
# ** Custo reduzido de 0.004880 >>> 0.004841 ... SALVANDO CHECKPOINT
#
# ÉPOCA  16 FINALIZADA: custo 0.004790 | MAE 0.048200
# ** Custo reduzido de 0.004841 >>> 0.004790 ... SALVANDO CHECKPOINT
#
# ÉPOCA  17 FINALIZADA: custo 0.004789 | MAE 0.048185
# ** Custo reduzido de 0.004790 >>> 0.004789 ... SALVANDO CHECKPOINT
#
# ÉPOCA  18 FINALIZADA: custo 0.004749 | MAE 0.047979
# ** Custo reduzido de 0.004789 >>> 0.004749 ... SALVANDO CHECKPOINT
#
# ÉPOCA  19 FINALIZADA: custo 0.004730 | MAE 0.047833
# ** Custo reduzido de 0.004749 >>> 0.004730 ... SALVANDO CHECKPOINT
#
# ÉPOCA  20 FINALIZADA: custo 0.004685 | MAE 0.047570
# ** Custo reduzido de 0.004730 >>> 0.004685 ... SALVANDO CHECKPOINT
#
# ÉPOCA  21 FINALIZADA: custo 0.004696 | MAE 0.047642
# **Custo não reduziu, não salva checkpoint
#
# ÉPOCA  22 FINALIZADA: custo 0.004667 | MAE 0.047536
# ** Custo reduzido de 0.004685 >>> 0.004667 ... SALVANDO CHECKPOINT
#
# ÉPOCA  23 FINALIZADA: custo 0.004643 | MAE 0.047322
# ** Custo reduzido de 0.004667 >>> 0.004643 ... SALVANDO CHECKPOINT
#
# ÉPOCA  24 FINALIZADA: custo 0.004608 | MAE 0.047213
# ** Custo reduzido de 0.004643 >>> 0.004608 ... SALVANDO CHECKPOINT
#
# ÉPOCA  25 FINALIZADA: custo 0.004563 | MAE 0.046919
# ** Custo reduzido de 0.004608 >>> 0.004563 ... SALVANDO CHECKPOINT
#
# ÉPOCA  26 FINALIZADA: custo 0.004552 | MAE 0.046839
# ** Custo reduzido de 0.004563 >>> 0.004552 ... SALVANDO CHECKPOINT
#
# ÉPOCA  27 FINALIZADA: custo 0.004506 | MAE 0.046586
# ** Custo reduzido de 0.004552 >>> 0.004506 ... SALVANDO CHECKPOINT
#
# ÉPOCA  28 FINALIZADA: custo 0.004477 | MAE 0.046689
# ** Custo reduzido de 0.004506 >>> 0.004477 ... SALVANDO CHECKPOINT
#
# ÉPOCA  29 FINALIZADA: custo 0.004418 | MAE 0.046085
# ** Custo reduzido de 0.004477 >>> 0.004418 ... SALVANDO CHECKPOINT
#
# ÉPOCA  30 FINALIZADA: custo 0.004401 | MAE 0.046105
# ** Custo reduzido de 0.004418 >>> 0.004401 ... SALVANDO CHECKPOINT
#
# ÉPOCA  31 FINALIZADA: custo 0.004361 | MAE 0.045798
# ** Custo reduzido de 0.004401 >>> 0.004361 ... SALVANDO CHECKPOINT
#
# ÉPOCA  32 FINALIZADA: custo 0.004331 | MAE 0.045695
# ** Custo reduzido de 0.004361 >>> 0.004331 ... SALVANDO CHECKPOINT
#
# ÉPOCA  33 FINALIZADA: custo 0.004308 | MAE 0.045628
# ** Custo reduzido de 0.004331 >>> 0.004308 ... SALVANDO CHECKPOINT
#
# ÉPOCA  34 FINALIZADA: custo 0.004278 | MAE 0.045287
# ** Custo reduzido de 0.004308 >>> 0.004278 ... SALVANDO CHECKPOINT
#
# ÉPOCA  35 FINALIZADA: custo 0.004245 | MAE 0.045253
# ** Custo reduzido de 0.004278 >>> 0.004245 ... SALVANDO CHECKPOINT
#
# ÉPOCA  36 FINALIZADA: custo 0.004234 | MAE 0.045138
# ** Custo reduzido de 0.004245 >>> 0.004234 ... SALVANDO CHECKPOINT
#
# ÉPOCA  37 FINALIZADA: custo 0.004239 | MAE 0.045110
# **Custo não reduziu, não salva checkpoint
#
# ÉPOCA  38 FINALIZADA: custo 0.004178 | MAE 0.044765
# ** Custo reduzido de 0.004234 >>> 0.004178 ... SALVANDO CHECKPOINT
#
# ÉPOCA  39 FINALIZADA: custo 0.004174 | MAE 0.044846
# ** Custo reduzido de 0.004178 >>> 0.004174 ... SALVANDO CHECKPOINT
#
# ÉPOCA  40 FINALIZADA: custo 0.004111 | MAE 0.044455
# ** Custo reduzido de 0.004174 >>> 0.004111 ... SALVANDO CHECKPOINT
#
# ÉPOCA  41 FINALIZADA: custo 0.004098 | MAE 0.044425
# ** Custo reduzido de 0.004111 >>> 0.004098 ... SALVANDO CHECKPOINT
#
# ÉPOCA  42 FINALIZADA: custo 0.004130 | MAE 0.044482
# **Custo não reduziu, não salva checkpoint
#
# ÉPOCA  43 FINALIZADA: custo 0.004081 | MAE 0.044236
# ** Custo reduzido de 0.004098 >>> 0.004081 ... SALVANDO CHECKPOINT
#
# ÉPOCA  44 FINALIZADA: custo 0.004074 | MAE 0.044190
# ** Custo reduzido de 0.004081 >>> 0.004074 ... SALVANDO CHECKPOINT
#
# ÉPOCA  45 FINALIZADA: custo 0.003995 | MAE 0.043743
# ** Custo reduzido de 0.004074 >>> 0.003995 ... SALVANDO CHECKPOINT
#
# ÉPOCA  46 FINALIZADA: custo 0.004006 | MAE 0.043838
# **Custo não reduziu, não salva checkpoint
#
# ÉPOCA  47 FINALIZADA: custo 0.003983 | MAE 0.043736
# ** Custo reduzido de 0.003995 >>> 0.003983 ... SALVANDO CHECKPOINT
#
# ÉPOCA  48 FINALIZADA: custo 0.003947 | MAE 0.043518
# ** Custo reduzido de 0.003983 >>> 0.003947 ... SALVANDO CHECKPOINT
#
# ÉPOCA  49 FINALIZADA: custo 0.003902 | MAE 0.043350
# ** Custo reduzido de 0.003947 >>> 0.003902 ... SALVANDO CHECKPOINT
#
# ÉPOCA  50 FINALIZADA: custo 0.003946 | MAE 0.043402
# **Custo não reduziu, não salva checkpoint
#
# ÉPOCA  51 FINALIZADA: custo 0.003876 | MAE 0.043108
# ** Custo reduzido de 0.003902 >>> 0.003876 ... SALVANDO CHECKPOINT
#
# ÉPOCA  52 FINALIZADA: custo 0.003865 | MAE 0.043026
# ** Custo reduzido de 0.003876 >>> 0.003865 ... SALVANDO CHECKPOINT
#
# ÉPOCA  53 FINALIZADA: custo 0.003847 | MAE 0.042915
# ** Custo reduzido de 0.003865 >>> 0.003847 ... SALVANDO CHECKPOINT
#
# ÉPOCA  54 FINALIZADA: custo 0.003795 | MAE 0.042662
# ** Custo reduzido de 0.003847 >>> 0.003795 ... SALVANDO CHECKPOINT
#
# ÉPOCA  55 FINALIZADA: custo 0.003781 | MAE 0.042578
# ** Custo reduzido de 0.003795 >>> 0.003781 ... SALVANDO CHECKPOINT
#
# ÉPOCA  56 FINALIZADA: custo 0.003780 | MAE 0.042455
# ** Custo reduzido de 0.003781 >>> 0.003780 ... SALVANDO CHECKPOINT
#
# ÉPOCA  57 FINALIZADA: custo 0.003771 | MAE 0.042512
# ** Custo reduzido de 0.003780 >>> 0.003771 ... SALVANDO CHECKPOINT
#
# ÉPOCA  58 FINALIZADA: custo 0.003759 | MAE 0.042420
# ** Custo reduzido de 0.003771 >>> 0.003759 ... SALVANDO CHECKPOINT
#
# ÉPOCA  59 FINALIZADA: custo 0.003706 | MAE 0.042228
# ** Custo reduzido de 0.003759 >>> 0.003706 ... SALVANDO CHECKPOINT
#
# ÉPOCA  60 FINALIZADA: custo 0.003679 | MAE 0.042009
# ** Custo reduzido de 0.003706 >>> 0.003679 ... SALVANDO CHECKPOINT
#
# ÉPOCA  61 FINALIZADA: custo 0.003732 | MAE 0.042219
# **Custo não reduziu, não salva checkpoint
#
# ÉPOCA  62 FINALIZADA: custo 0.003667 | MAE 0.041951
# ** Custo reduzido de 0.003679 >>> 0.003667 ... SALVANDO CHECKPOINT
#
# ÉPOCA  63 FINALIZADA: custo 0.003663 | MAE 0.041793
# ** Custo reduzido de 0.003667 >>> 0.003663 ... SALVANDO CHECKPOINT
#
# ÉPOCA  64 FINALIZADA: custo 0.003624 | MAE 0.041718
# ** Custo reduzido de 0.003663 >>> 0.003624 ... SALVANDO CHECKPOINT
#
# ÉPOCA  65 FINALIZADA: custo 0.003608 | MAE 0.041724
# ** Custo reduzido de 0.003624 >>> 0.003608 ... SALVANDO CHECKPOINT
#
# ÉPOCA  66 FINALIZADA: custo 0.003602 | MAE 0.041492
# ** Custo reduzido de 0.003608 >>> 0.003602 ... SALVANDO CHECKPOINT
#
# ÉPOCA  67 FINALIZADA: custo 0.003522 | MAE 0.041064
# ** Custo reduzido de 0.003602 >>> 0.003522 ... SALVANDO CHECKPOINT
#
# ÉPOCA  68 FINALIZADA: custo 0.003542 | MAE 0.041292
# **Custo não reduziu, não salva checkpoint
#
# ÉPOCA  69 FINALIZADA: custo 0.003544 | MAE 0.041135
# **Custo não reduziu, não salva checkpoint
#
# ÉPOCA  70 FINALIZADA: custo 0.003523 | MAE 0.041080
# **Custo não reduziu, não salva checkpoint
#
# ÉPOCA  71 FINALIZADA: custo 0.003487 | MAE 0.040873
# ** Custo reduzido de 0.003522 >>> 0.003487 ... SALVANDO CHECKPOINT
#
# ÉPOCA  72 FINALIZADA: custo 0.003458 | MAE 0.040849
# ** Custo reduzido de 0.003487 >>> 0.003458 ... SALVANDO CHECKPOINT
#
# ÉPOCA  73 FINALIZADA: custo 0.003452 | MAE 0.040824
# ** Custo reduzido de 0.003458 >>> 0.003452 ... SALVANDO CHECKPOINT
#
# ÉPOCA  74 FINALIZADA: custo 0.003400 | MAE 0.040482
# ** Custo reduzido de 0.003452 >>> 0.003400 ... SALVANDO CHECKPOINT
#
# ÉPOCA  75 FINALIZADA: custo 0.003396 | MAE 0.040448
# ** Custo reduzido de 0.003400 >>> 0.003396 ... SALVANDO CHECKPOINT
#
# ÉPOCA  76 FINALIZADA: custo 0.003381 | MAE 0.040446
# ** Custo reduzido de 0.003396 >>> 0.003381 ... SALVANDO CHECKPOINT
#
# ÉPOCA  77 FINALIZADA: custo 0.003415 | MAE 0.040435
# **Custo não reduziu, não salva checkpoint
#
# ÉPOCA  78 FINALIZADA: custo 0.003418 | MAE 0.040555
# **Custo não reduziu, não salva checkpoint
#
# ÉPOCA  79 FINALIZADA: custo 0.003267 | MAE 0.039803
# ** Custo reduzido de 0.003381 >>> 0.003267 ... SALVANDO CHECKPOINT
#
# ÉPOCA  80 FINALIZADA: custo 0.003313 | MAE 0.040013
# **Custo não reduziu, não salva checkpoint
#
# ÉPOCA  81 FINALIZADA: custo 0.003311 | MAE 0.039893
# **Custo não reduziu, não salva checkpoint
#
# ÉPOCA  82 FINALIZADA: custo 0.003282 | MAE 0.039630
# **Custo não reduziu, não salva checkpoint
#
# ÉPOCA  83 FINALIZADA: custo 0.003346 | MAE 0.040173
# **Custo não reduziu, não salva checkpoint
#
# ÉPOCA  84 FINALIZADA: custo 0.003230 | MAE 0.039541
# ** Custo reduzido de 0.003267 >>> 0.003230 ... SALVANDO CHECKPOINT
#
# ÉPOCA  85 FINALIZADA: custo 0.003221 | MAE 0.039570
# ** Custo reduzido de 0.003230 >>> 0.003221 ... SALVANDO CHECKPOINT
#
# ÉPOCA  86 FINALIZADA: custo 0.003241 | MAE 0.039466
# **Custo não reduziu, não salva checkpoint
#
# ÉPOCA  87 FINALIZADA: custo 0.003251 | MAE 0.039656
# **Custo não reduziu, não salva checkpoint
#
# ÉPOCA  88 FINALIZADA: custo 0.003172 | MAE 0.039211
# ** Custo reduzido de 0.003221 >>> 0.003172 ... SALVANDO CHECKPOINT
#
# ÉPOCA  89 FINALIZADA: custo 0.003155 | MAE 0.039094
# ** Custo reduzido de 0.003172 >>> 0.003155 ... SALVANDO CHECKPOINT
#
# ÉPOCA  90 FINALIZADA: custo 0.003192 | MAE 0.039421
# **Custo não reduziu, não salva checkpoint
#
# ÉPOCA  91 FINALIZADA: custo 0.003135 | MAE 0.038923
# ** Custo reduzido de 0.003155 >>> 0.003135 ... SALVANDO CHECKPOINT
#
# ÉPOCA  92 FINALIZADA: custo 0.003104 | MAE 0.038772
# ** Custo reduzido de 0.003135 >>> 0.003104 ... SALVANDO CHECKPOINT
#
# ÉPOCA  93 FINALIZADA: custo 0.003116 | MAE 0.038848
# **Custo não reduziu, não salva checkpoint
#
# ÉPOCA  94 FINALIZADA: custo 0.003081 | MAE 0.038673
# ** Custo reduzido de 0.003104 >>> 0.003081 ... SALVANDO CHECKPOINT
#
# ÉPOCA  95 FINALIZADA: custo 0.003088 | MAE 0.038722
# **Custo não reduziu, não salva checkpoint
#
# ÉPOCA  96 FINALIZADA: custo 0.003150 | MAE 0.039091
# **Custo não reduziu, não salva checkpoint
#
# ÉPOCA  97 FINALIZADA: custo 0.003017 | MAE 0.038250
# ** Custo reduzido de 0.003081 >>> 0.003017 ... SALVANDO CHECKPOINT
#
# ÉPOCA  98 FINALIZADA: custo 0.003005 | MAE 0.038283
# ** Custo reduzido de 0.003017 >>> 0.003005 ... SALVANDO CHECKPOINT
#
# ÉPOCA  99 FINALIZADA: custo 0.002987 | MAE 0.038153
# ** Custo reduzido de 0.003005 >>> 0.002987 ... SALVANDO CHECKPOINT
#
# ÉPOCA 100 FINALIZADA: custo 0.003045 | MAE 0.038454
# **Custo não reduziu, não salva checkpoint
#
# ÉPOCA 101 FINALIZADA: custo 0.002962 | MAE 0.038046
# ** Custo reduzido de 0.002987 >>> 0.002962 ... SALVANDO CHECKPOINT
#
# ÉPOCA 102 FINALIZADA: custo 0.002920 | MAE 0.037779
# ** Custo reduzido de 0.002962 >>> 0.002920 ... SALVANDO CHECKPOINT
#
# ÉPOCA 103 FINALIZADA: custo 0.002936 | MAE 0.037845
# **Custo não reduziu, não salva checkpoint
#
# ÉPOCA 104 FINALIZADA: custo 0.003012 | MAE 0.038174
# **Custo não reduziu, não salva checkpoint
#
# ÉPOCA 105 FINALIZADA: custo 0.002891 | MAE 0.037746
# ** Custo reduzido de 0.002920 >>> 0.002891 ... SALVANDO CHECKPOINT
#
# ÉPOCA 106 FINALIZADA: custo 0.002962 | MAE 0.038017
# **Custo não reduziu, não salva checkpoint
#
# ÉPOCA 107 FINALIZADA: custo 0.002936 | MAE 0.037817
# **Custo não reduziu, não salva checkpoint
#
# ÉPOCA 108 FINALIZADA: custo 0.002926 | MAE 0.037834
# **Custo não reduziu, não salva checkpoint
#
# ÉPOCA 109 FINALIZADA: custo 0.002838 | MAE 0.037328
# ** Custo reduzido de 0.002891 >>> 0.002838 ... SALVANDO CHECKPOINT
#
# ÉPOCA 110 FINALIZADA: custo 0.002855 | MAE 0.037362
# **Custo não reduziu, não salva checkpoint
#
# ÉPOCA 111 FINALIZADA: custo 0.002870 | MAE 0.037472
# **Custo não reduziu, não salva checkpoint
#
# ÉPOCA 112 FINALIZADA: custo 0.002826 | MAE 0.037298
# ** Custo reduzido de 0.002838 >>> 0.002826 ... SALVANDO CHECKPOINT
#
# ÉPOCA 113 FINALIZADA: custo 0.002830 | MAE 0.037338
# **Custo não reduziu, não salva checkpoint
#
# ÉPOCA 114 FINALIZADA: custo 0.002816 | MAE 0.037105
# ** Custo reduzido de 0.002826 >>> 0.002816 ... SALVANDO CHECKPOINT
#
# ÉPOCA 115 FINALIZADA: custo 0.002781 | MAE 0.036902
# ** Custo reduzido de 0.002816 >>> 0.002781 ... SALVANDO CHECKPOINT
#
# ÉPOCA 116 FINALIZADA: custo 0.002764 | MAE 0.036889
# ** Custo reduzido de 0.002781 >>> 0.002764 ... SALVANDO CHECKPOINT
#
# ÉPOCA 117 FINALIZADA: custo 0.002777 | MAE 0.036850
# **Custo não reduziu, não salva checkpoint
#
# ÉPOCA 118 FINALIZADA: custo 0.002751 | MAE 0.036792
# ** Custo reduzido de 0.002764 >>> 0.002751 ... SALVANDO CHECKPOINT
#
# ÉPOCA 119 FINALIZADA: custo 0.002736 | MAE 0.036745
# ** Custo reduzido de 0.002751 >>> 0.002736 ... SALVANDO CHECKPOINT
#
# ÉPOCA 120 FINALIZADA: custo 0.002752 | MAE 0.036767
# **Custo não reduziu, não salva checkpoint
#
# ÉPOCA 121 FINALIZADA: custo 0.002695 | MAE 0.036533
# ** Custo reduzido de 0.002736 >>> 0.002695 ... SALVANDO CHECKPOINT
#
# ÉPOCA 122 FINALIZADA: custo 0.002707 | MAE 0.036463
# **Custo não reduziu, não salva checkpoint
#
# ÉPOCA 123 FINALIZADA: custo 0.002667 | MAE 0.036408
# ** Custo reduzido de 0.002695 >>> 0.002667 ... SALVANDO CHECKPOINT
#
# ÉPOCA 124 FINALIZADA: custo 0.002656 | MAE 0.036400
# ** Custo reduzido de 0.002667 >>> 0.002656 ... SALVANDO CHECKPOINT
#
# ÉPOCA 125 FINALIZADA: custo 0.002664 | MAE 0.036242
# **Custo não reduziu, não salva checkpoint
#
# ÉPOCA 126 FINALIZADA: custo 0.002650 | MAE 0.036242
# ** Custo reduzido de 0.002656 >>> 0.002650 ... SALVANDO CHECKPOINT
#
# ÉPOCA 127 FINALIZADA: custo 0.002632 | MAE 0.036140
# ** Custo reduzido de 0.002650 >>> 0.002632 ... SALVANDO CHECKPOINT
#
# ÉPOCA 128 FINALIZADA: custo 0.002643 | MAE 0.036137
# **Custo não reduziu, não salva checkpoint
#
# ÉPOCA 129 FINALIZADA: custo 0.002677 | MAE 0.036427
# **Custo não reduziu, não salva checkpoint
#
# ÉPOCA 130 FINALIZADA: custo 0.002589 | MAE 0.035850
# ** Custo reduzido de 0.002632 >>> 0.002589 ... SALVANDO CHECKPOINT
#
# ÉPOCA 131 FINALIZADA: custo 0.002597 | MAE 0.035827
# **Custo não reduziu, não salva checkpoint
#
# ÉPOCA 132 FINALIZADA: custo 0.002595 | MAE 0.035829
# **Custo não reduziu, não salva checkpoint
#
# ÉPOCA 133 FINALIZADA: custo 0.002526 | MAE 0.035403
# ** Custo reduzido de 0.002589 >>> 0.002526 ... SALVANDO CHECKPOINT
#
# ÉPOCA 134 FINALIZADA: custo 0.002575 | MAE 0.035717
# **Custo não reduziu, não salva checkpoint
#
# ÉPOCA 135 FINALIZADA: custo 0.002542 | MAE 0.035527
# **Custo não reduziu, não salva checkpoint
#
# ÉPOCA 136 FINALIZADA: custo 0.002510 | MAE 0.035395
# ** Custo reduzido de 0.002526 >>> 0.002510 ... SALVANDO CHECKPOINT
#
# ÉPOCA 137 FINALIZADA: custo 0.002549 | MAE 0.035581
# **Custo não reduziu, não salva checkpoint
#
# ÉPOCA 138 FINALIZADA: custo 0.002490 | MAE 0.035108
# ** Custo reduzido de 0.002510 >>> 0.002490 ... SALVANDO CHECKPOINT
#
# ÉPOCA 139 FINALIZADA: custo 0.002541 | MAE 0.035514
# **Custo não reduziu, não salva checkpoint
#
# ÉPOCA 140 FINALIZADA: custo 0.002508 | MAE 0.035282
# **Custo não reduziu, não salva checkpoint
#
# ÉPOCA 141 FINALIZADA: custo 0.002499 | MAE 0.035293
# **Custo não reduziu, não salva checkpoint
#
# ÉPOCA 142 FINALIZADA: custo 0.002469 | MAE 0.035081
# ** Custo reduzido de 0.002490 >>> 0.002469 ... SALVANDO CHECKPOINT
#
# ÉPOCA 143 FINALIZADA: custo 0.002457 | MAE 0.035059
# ** Custo reduzido de 0.002469 >>> 0.002457 ... SALVANDO CHECKPOINT
#
# ÉPOCA 144 FINALIZADA: custo 0.002405 | MAE 0.034753
# ** Custo reduzido de 0.002457 >>> 0.002405 ... SALVANDO CHECKPOINT
#
# ÉPOCA 145 FINALIZADA: custo 0.002454 | MAE 0.034856
# **Custo não reduziu, não salva checkpoint
#
# ÉPOCA 146 FINALIZADA: custo 0.002431 | MAE 0.034838
# **Custo não reduziu, não salva checkpoint
#
# ÉPOCA 147 FINALIZADA: custo 0.002413 | MAE 0.034703
# **Custo não reduziu, não salva checkpoint
#
# ÉPOCA 148 FINALIZADA: custo 0.002444 | MAE 0.034875
# **Custo não reduziu, não salva checkpoint
#
# ÉPOCA 149 FINALIZADA: custo 0.002387 | MAE 0.034463
# ** Custo reduzido de 0.002405 >>> 0.002387 ... SALVANDO CHECKPOINT
#
# ÉPOCA 150 FINALIZADA: custo 0.002367 | MAE 0.034406
# ** Custo reduzido de 0.002387 >>> 0.002367 ... SALVANDO CHECKPOINT
#
# ÉPOCA 151 FINALIZADA: custo 0.002387 | MAE 0.034480
# **Custo não reduziu, não salva checkpoint
#
# ÉPOCA 152 FINALIZADA: custo 0.002374 | MAE 0.034493
# **Custo não reduziu, não salva checkpoint
#
# ÉPOCA 153 FINALIZADA: custo 0.002345 | MAE 0.034474
# ** Custo reduzido de 0.002367 >>> 0.002345 ... SALVANDO CHECKPOINT
#
# ÉPOCA 154 FINALIZADA: custo 0.002356 | MAE 0.034281
# **Custo não reduziu, não salva checkpoint
#
# ÉPOCA 155 FINALIZADA: custo 0.002435 | MAE 0.034727
# **Custo não reduziu, não salva checkpoint
#
# ÉPOCA 156 FINALIZADA: custo 0.002363 | MAE 0.034341
# **Custo não reduziu, não salva checkpoint
#
# ÉPOCA 157 FINALIZADA: custo 0.002344 | MAE 0.034218
# ** Custo reduzido de 0.002345 >>> 0.002344 ... SALVANDO CHECKPOINT
#
# ÉPOCA 158 FINALIZADA: custo 0.002286 | MAE 0.034010
# ** Custo reduzido de 0.002344 >>> 0.002286 ... SALVANDO CHECKPOINT
#
# ÉPOCA 159 FINALIZADA: custo 0.002453 | MAE 0.034751
# **Custo não reduziu, não salva checkpoint
#
# ÉPOCA 160 FINALIZADA: custo 0.002331 | MAE 0.034154
# **Custo não reduziu, não salva checkpoint
#
# ÉPOCA 161 FINALIZADA: custo 0.002250 | MAE 0.033757
# ** Custo reduzido de 0.002286 >>> 0.002250 ... SALVANDO CHECKPOINT
#
# ÉPOCA 162 FINALIZADA: custo 0.002318 | MAE 0.034010
# **Custo não reduziu, não salva checkpoint
#
# ÉPOCA 163 FINALIZADA: custo 0.002280 | MAE 0.033746
# **Custo não reduziu, não salva checkpoint
#
# ÉPOCA 164 FINALIZADA: custo 0.002288 | MAE 0.033861
# **Custo não reduziu, não salva checkpoint
#
# ÉPOCA 165 FINALIZADA: custo 0.002283 | MAE 0.033649
# **Custo não reduziu, não salva checkpoint
#
# ÉPOCA 166 FINALIZADA: custo 0.002267 | MAE 0.033626
# **Custo não reduziu, não salva checkpoint
#
# --Critério de redução de taxa de aprendizagem alcançado, reduzindo LR.
# ÉPOCA 167 FINALIZADA: custo 0.002039 | MAE 0.032233
# ** Custo reduzido de 0.002250 >>> 0.002039 ... SALVANDO CHECKPOINT
#
# ÉPOCA 168 FINALIZADA: custo 0.001977 | MAE 0.031755
# ** Custo reduzido de 0.002039 >>> 0.001977 ... SALVANDO CHECKPOINT
#
# ÉPOCA 169 FINALIZADA: custo 0.001940 | MAE 0.031509
# ** Custo reduzido de 0.001977 >>> 0.001940 ... SALVANDO CHECKPOINT
#
# ÉPOCA 170 FINALIZADA: custo 0.001989 | MAE 0.031870
# **Custo não reduziu, não salva checkpoint
#
# ÉPOCA 171 FINALIZADA: custo 0.001950 | MAE 0.031471
# **Custo não reduziu, não salva checkpoint
#
# ÉPOCA 172 FINALIZADA: custo 0.001953 | MAE 0.031468
# **Custo não reduziu, não salva checkpoint
#
# ÉPOCA 173 FINALIZADA: custo 0.001923 | MAE 0.031266
# ** Custo reduzido de 0.001940 >>> 0.001923 ... SALVANDO CHECKPOINT
#
# ÉPOCA 174 FINALIZADA: custo 0.001930 | MAE 0.031340
# **Custo não reduziu, não salva checkpoint
#
# ÉPOCA 175 FINALIZADA: custo 0.001912 | MAE 0.031284
# ** Custo reduzido de 0.001923 >>> 0.001912 ... SALVANDO CHECKPOINT
#
# ÉPOCA 176 FINALIZADA: custo 0.001907 | MAE 0.031237
# ** Custo reduzido de 0.001912 >>> 0.001907 ... SALVANDO CHECKPOINT
#
# ÉPOCA 177 FINALIZADA: custo 0.001912 | MAE 0.031296
# **Custo não reduziu, não salva checkpoint
#
# ÉPOCA 178 FINALIZADA: custo 0.001907 | MAE 0.031229
# ** Custo reduzido de 0.001907 >>> 0.001907 ... SALVANDO CHECKPOINT
#
# ÉPOCA 179 FINALIZADA: custo 0.001905 | MAE 0.031243
# ** Custo reduzido de 0.001907 >>> 0.001905 ... SALVANDO CHECKPOINT
#
# ÉPOCA 180 FINALIZADA: custo 0.001890 | MAE 0.031189
# ** Custo reduzido de 0.001905 >>> 0.001890 ... SALVANDO CHECKPOINT
#
# ÉPOCA 181 FINALIZADA: custo 0.001905 | MAE 0.031247
# **Custo não reduziu, não salva checkpoint
#
# ÉPOCA 182 FINALIZADA: custo 0.001897 | MAE 0.031156
# **Custo não reduziu, não salva checkpoint
#
# ÉPOCA 183 FINALIZADA: custo 0.001879 | MAE 0.031098
# ** Custo reduzido de 0.001890 >>> 0.001879 ... SALVANDO CHECKPOINT
#
# ÉPOCA 184 FINALIZADA: custo 0.001870 | MAE 0.030969
# ** Custo reduzido de 0.001879 >>> 0.001870 ... SALVANDO CHECKPOINT
#
# ÉPOCA 185 FINALIZADA: custo 0.001898 | MAE 0.031112
# **Custo não reduziu, não salva checkpoint
#
# ÉPOCA 186 FINALIZADA: custo 0.001863 | MAE 0.030941
# ** Custo reduzido de 0.001870 >>> 0.001863 ... SALVANDO CHECKPOINT
#
# ÉPOCA 187 FINALIZADA: custo 0.001854 | MAE 0.030882
# ** Custo reduzido de 0.001863 >>> 0.001854 ... SALVANDO CHECKPOINT
#
# ÉPOCA 188 FINALIZADA: custo 0.001850 | MAE 0.030859
# ** Custo reduzido de 0.001854 >>> 0.001850 ... SALVANDO CHECKPOINT
#
# ÉPOCA 189 FINALIZADA: custo 0.001868 | MAE 0.031014
# **Custo não reduziu, não salva checkpoint
#
# ÉPOCA 190 FINALIZADA: custo 0.001867 | MAE 0.030956
# **Custo não reduziu, não salva checkpoint
#
# ÉPOCA 191 FINALIZADA: custo 0.001856 | MAE 0.030822
# **Custo não reduziu, não salva checkpoint
#
# ÉPOCA 192 FINALIZADA: custo 0.001858 | MAE 0.030959
# **Custo não reduziu, não salva checkpoint
#
# ÉPOCA 193 FINALIZADA: custo 0.001829 | MAE 0.030636
# ** Custo reduzido de 0.001850 >>> 0.001829 ... SALVANDO CHECKPOINT
#
# ÉPOCA 194 FINALIZADA: custo 0.001844 | MAE 0.030793
# **Custo não reduziu, não salva checkpoint
#
# ÉPOCA 195 FINALIZADA: custo 0.001848 | MAE 0.030870
# **Custo não reduziu, não salva checkpoint
#
# ÉPOCA 196 FINALIZADA: custo 0.001835 | MAE 0.030603
# **Custo não reduziu, não salva checkpoint
#
# ÉPOCA 197 FINALIZADA: custo 0.001819 | MAE 0.030566
# ** Custo reduzido de 0.001829 >>> 0.001819 ... SALVANDO CHECKPOINT
#
# ÉPOCA 198 FINALIZADA: custo 0.001837 | MAE 0.030646
# **Custo não reduziu, não salva checkpoint
#
# ÉPOCA 199 FINALIZADA: custo 0.001821 | MAE 0.030565
# **Custo não reduziu, não salva checkpoint
#
# ÉPOCA 200 FINALIZADA: custo 0.001816 | MAE 0.030522
# ** Custo reduzido de 0.001819 >>> 0.001816 ... SALVANDO CHECKPOINT

# %%
fig, ax = plt.subplots(1,2, figsize=(14,6))

ax[0].plot(arr_loss, label='Perda')
ax[0].set(xlabel='ÉPOCA', ylabel='PERDA', title='PROGRESSÃO DA PERDA NO TREINAMENTO')
ax[0].grid()

ax[1].plot(arr_mae, label='MAE')
ax[1].set(xlabel='ÉPOCA', ylabel='MAE', title='PROGRESSÃO DO MAE NO TREINAMENTO')
ax[1].grid()

plt.tight_layout();

# %% [markdown]
# ## Etapa 5: Processamento da base de teste

# %%
X_test = torch.tensor(X_test, device=device, dtype=torch.float32)

# %% [markdown]
# ## Etapa 6: Previsões

# %%
#reg = Reg_LSTM()
#reg.load_state_dict(torch.load('/content/checkpoint.pth'))
#reg.to(device)
reg.eval()
# Out:
# Reg_LSTM(
#   (lstm0): LSTM(6, 100)
#   (lstm1): LSTM(100, 50)
#   (lstm2): LSTM(50, 50, num_layers=2, dropout=0.3)
#   (dropout): Dropout(p=0.3, inplace=False)
#   (linear): Linear(in_features=50, out_features=1, bias=True)
# )

# %%
predicted = reg(X_test.to(device))

# %%
y_scaler = MinMaxScaler()
y_scaler.fit(data_raw[:,0].reshape(-1,1))
# Out:
# MinMaxScaler(copy=True, feature_range=(0, 1))

# %%
predicted = predicted[-1]
predicted = predicted.detach().cpu().numpy().reshape(-1,1)

# %%
predicted = y_scaler.inverse_transform(predicted)
predicted
# Out:
# array([[101.95234 ],
#        [ 69.07735 ],
#        [ 16.445549],
#        ...,
#        [239.37115 ],
#        [382.35992 ],
#        [ 69.36774 ]], dtype=float32)

# %%
y_test = y_scaler.inverse_transform(y_test.reshape(-1,1))

# %%
y_test.mean(), predicted.mean()
# Out:
# (99.98163819255947, 98.31233)

# %%
mean_absolute_error(y_test, predicted)
# Out:
# 33.72914318899063

# %%
plt.figure(figsize=(14,6))
plt.plot(y_test, color='b', label= 'POLUIÇÃO REAL')
plt.plot(predicted, alpha=0.7, color='r', label='PREVISÕES')
plt.title('Previsão poluição')
plt.xlabel('Horas')
plt.ylabel('Valor poluição')
plt.legend()
plt.grid()
plt.show()
